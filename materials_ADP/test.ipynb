# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 6 + 4*X + np.random.randn(100, 1)

plt.scatter(X, y)

# %%
a, b = np.random.rand(), np.random.rand()
mu = 0.05
epoch = 100

for i in range(epoch):
    y_pred = a*X + b
    e = y_pred - y
    a = a - mu*(X*e).mean() #Loss function을 미분한 수식에 따름
    b = b - mu*(e).mean()   #Loss function을 미분한 수식에 따름
    print("a=", a.round(3), "b=", b.round(3), "error=", np.abs(e).mean().round(3))
    
xs = np.linspace(0,2,2)
ys = a*xs + b

plt.scatter(X, y)
plt.plot(xs,ys, c='r')
# Out:
# a= 1.221 b= 1.174 error= 8.502
# a= 1.628 b= 1.556 error= 7.647
# a= 1.992 b= 1.9 error= 6.879
# a= 2.318 b= 2.21 error= 6.191
# a= 2.608 b= 2.488 error= 5.574
# a= 2.868 b= 2.739 error= 5.02
# a= 3.101 b= 2.965 error= 4.523
# a= 3.308 b= 3.169 error= 4.077
# a= 3.493 b= 3.353 error= 3.678
# a= 3.657 b= 3.519 error= 3.319
# a= 3.804 b= 3.669 error= 2.997
# a= 3.935 b= 3.804 error= 2.708
# a= 4.051 b= 3.927 error= 2.449
# a= 4.155 b= 4.038 error= 2.217
# a= 4.247 b= 4.138 error= 2.008
# a= 4.328 b= 4.229 error= 1.821
# a= 4.4 b= 4.312 error= 1.659
# a= 4.464 b= 4.387 error= 1.523
# a= 4.521 b= 4.455 error= 1.41
# a= 4.57 b= 4.517 error= 1.326
# a= 4.614 b= 4.574 error= 1.255
# a= 4.652 b= 4.626 error= 1.202
# a= 4.686 b= 4.674 error= 1.163
# a= 4.715 b= 4.717 error= 1.133
# a= 4.74 b= 4.757 error= 1.108
# a= 4.762 b= 4.794 error= 1.085
# a= 4.781 b= 4.828 error= 1.066
# a= 4.797 b= 4.859 error= 1.049
# a= 4.811 b= 4.888 error= 1.036
# a= 4.822 b= 4.915 error= 1.025
# a= 4.832 b= 4.94 error= 1.016
# a= 4.839 b= 4.963 error= 1.008
# a= 4.845 b= 4.985 error= 1.002
# a= 4.85 b= 5.005 error= 0.996
# a= 4.854 b= 5.025 error= 0.991
# a= 4.856 b= 5.043 error= 0.988
# a= 4.857 b= 5.06 error= 0.984
# a= 4.858 b= 5.076 error= 0.981
# a= 4.857 b= 5.091 error= 0.978
# a= 4.856 b= 5.105 error= 0.975
# a= 4.855 b= 5.119 error= 0.973
# a= 4.853 b= 5.133 error= 0.97
# a= 4.85 b= 5.145 error= 0.968
# a= 4.847 b= 5.157 error= 0.966
# a= 4.843 b= 5.169 error= 0.964
# a= 4.839 b= 5.18 error= 0.961
# a= 4.835 b= 5.191 error= 0.959
# a= 4.831 b= 5.202 error= 0.957
# a= 4.826 b= 5.212 error= 0.955
# a= 4.821 b= 5.222 error= 0.953
# a= 4.816 b= 5.232 error= 0.951
# a= 4.811 b= 5.241 error= 0.949
# a= 4.806 b= 5.25 error= 0.947
# a= 4.8 b= 5.259 error= 0.945
# a= 4.795 b= 5.268 error= 0.944
# a= 4.789 b= 5.277 error= 0.942
# a= 4.784 b= 5.285 error= 0.94
# a= 4.778 b= 5.294 error= 0.939
# a= 4.772 b= 5.302 error= 0.937
# a= 4.766 b= 5.31 error= 0.936
# a= 4.761 b= 5.318 error= 0.935
# a= 4.755 b= 5.325 error= 0.933
# a= 4.749 b= 5.333 error= 0.932
# a= 4.743 b= 5.341 error= 0.93
# a= 4.737 b= 5.348 error= 0.929
# a= 4.731 b= 5.355 error= 0.928
# a= 4.726 b= 5.363 error= 0.926
# a= 4.72 b= 5.37 error= 0.925
# a= 4.714 b= 5.377 error= 0.924
# a= 4.708 b= 5.384 error= 0.922
# a= 4.703 b= 5.391 error= 0.921
# a= 4.697 b= 5.398 error= 0.92
# a= 4.691 b= 5.405 error= 0.919
# a= 4.685 b= 5.411 error= 0.918
# a= 4.68 b= 5.418 error= 0.917
# a= 4.674 b= 5.425 error= 0.916
# a= 4.669 b= 5.431 error= 0.915
# a= 4.663 b= 5.437 error= 0.914
# a= 4.658 b= 5.444 error= 0.913
# a= 4.652 b= 5.45 error= 0.912
# a= 4.647 b= 5.456 error= 0.911
# a= 4.641 b= 5.463 error= 0.91
# a= 4.636 b= 5.469 error= 0.909
# a= 4.631 b= 5.475 error= 0.908
# a= 4.625 b= 5.481 error= 0.908
# a= 4.62 b= 5.487 error= 0.907
# a= 4.615 b= 5.493 error= 0.906
# a= 4.61 b= 5.499 error= 0.905
# a= 4.605 b= 5.505 error= 0.905
# a= 4.599 b= 5.511 error= 0.904
# a= 4.594 b= 5.516 error= 0.903
# a= 4.589 b= 5.522 error= 0.902
# a= 4.584 b= 5.528 error= 0.901
# a= 4.579 b= 5.533 error= 0.901
# a= 4.575 b= 5.539 error= 0.9
# a= 4.57 b= 5.544 error= 0.899
# a= 4.565 b= 5.55 error= 0.899
# a= 4.56 b= 5.555 error= 0.898
# a= 4.555 b= 5.561 error= 0.897
# a= 4.551 b= 5.566 error= 0.896
